# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

"""
# matrix multiplications
A = np.floor(4*np.random.rand(3,3))
B = np.floor(4*np.random.rand(3,3))

print(A)
print(B)
print(A@B)               # matrix product, the same as np.matmul(A, B)
#print(B@A)              # Note that: not(A@B == B@A) 
#print(A*B)              # not the matrix product(!)
#print(np.inner(A, B.T)) # discouraged
#print(np.outer(A, B))   # outer product
#print(np.kron(A, B))    # Kronecker product
#print(np.dot(A, B))     # only if you know what you do
"""


# Matrix visualizations
image = imread('C:\\Users\\Tharald\\PycharmProjects\\PYHTON\\Assignments\\Assignment6\\SillyBillyCat.jpg')

print(type(image))
#plt.pcolor(np.flip(np.sum(image,axis=2)))
#plt.contour(np.sum(image, axis=2))
plt.imshow(image)
#plt.imshow(np.sum(image,axis=2), cmap='gray')
# Out:
# <class 'numpy.ndarray'>
